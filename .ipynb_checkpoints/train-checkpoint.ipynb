# %%
from fastai.vision.all import *
from fastai.callback.wandb import *
import wandb

# %%
path = Path('./data/')

# %%
block = DataBlock(
        blocks=(ImageBlock, CategoryBlock),
        get_items=get_image_files,
        splitter=RandomSplitter(valid_pct=0.2, seed=42),
        get_y=parent_label, item_tfms=[Resize(384)],
        batch_tfms=aug_transforms(mult=1.5, size=384, min_scale=0.75))

# %%
dls = block.dataloaders(path, bs=8)
dls.train.show_batch(max_n=8, nrows=1)

# %%
from timm import create_model
import timm
timm.list_models('*mobile*', pretrained=True)
# Out:
# ['mobilenetv2_050',
#  'mobilenetv2_100',
#  'mobilenetv2_110d',
#  'mobilenetv2_120d',
#  'mobilenetv2_140',
#  'mobilenetv3_large_100',
#  'mobilenetv3_large_100_miil',
#  'mobilenetv3_large_100_miil_in21k',
#  'mobilenetv3_rw',
#  'mobilenetv3_small_050',
#  'mobilenetv3_small_075',
#  'mobilenetv3_small_100',
#  'mobilevit_s',
#  'mobilevit_xs',
#  'mobilevit_xxs',
#  'tf_mobilenetv3_large_075',
#  'tf_mobilenetv3_large_100',
#  'tf_mobilenetv3_large_minimal_100',
#  'tf_mobilenetv3_small_075',
#  'tf_mobilenetv3_small_100',
#  'tf_mobilenetv3_small_minimal_100']

# %%
model = create_model('mobilevit_xxs', pretrained=True, num_classes=dls.c)
learn = Learner(dls, model, metrics=accuracy, loss_func=LabelSmoothingCrossEntropyFlat())

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.00013182566908653826)

# %%
with wandb.init(project="leaf-disease-blogpost", name="mobilevit_xxs"):
    learn.fine_tune(10, 3e-4, freeze_epochs=1, cbs=[WandbCallback(log_preds=False), SaveModelCallback(), ShowGraphCallback()]
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.076375</td>
#       <td>1.006263</td>
#       <td>0.916667</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.0062634944915771.
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.003941</td>
#       <td>0.968462</td>
#       <td>0.895833</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.969438</td>
#       <td>0.874913</td>
#       <td>0.958333</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.900839</td>
#       <td>0.703548</td>
#       <td>0.937500</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.818252</td>
#       <td>0.605157</td>
#       <td>0.958333</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.705513</td>
#       <td>0.472133</td>
#       <td>0.958333</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.614798</td>
#       <td>0.430970</td>
#       <td>0.979167</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.573098</td>
#       <td>0.432065</td>
#       <td>0.958333</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.540185</td>
#       <td>0.412554</td>
#       <td>0.958333</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.508107</td>
#       <td>0.407165</td>
#       <td>0.958333</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.478957</td>
#       <td>0.409087</td>
#       <td>0.937500</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.9684615731239319.
# Better model found at epoch 1 with valid_loss value: 0.8749133944511414.
# Better model found at epoch 2 with valid_loss value: 0.7035475373268127.
# Better model found at epoch 3 with valid_loss value: 0.6051565408706665.
# Better model found at epoch 4 with valid_loss value: 0.4721325933933258.
# Better model found at epoch 5 with valid_loss value: 0.4309704005718231.
# Better model found at epoch 7 with valid_loss value: 0.41255390644073486.
# Better model found at epoch 8 with valid_loss value: 0.4071650207042694.

# %%
interp = ClassificationInterpretation.from_learner(learn, dl=dls.train)
interp.plot_confusion_matrix(figsize=(5,5), dpi=60)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp = ClassificationInterpretation.from_learner(learn, dl=dls.valid)
interp.plot_confusion_matrix(figsize=(5,5), dpi=60)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.print_classification_report()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#               precision    recall  f1-score   support
#
#        blast       1.00      1.00      1.00        16
#       blight       0.92      0.92      0.92        13
#       tungro       0.95      0.95      0.95        19
#
#     accuracy                           0.96        48
#    macro avg       0.96      0.96      0.96        48
# weighted avg       0.96      0.96      0.96        48

# %%
interp.plot_top_losses(k=6)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn.load("model")
learn.export("models/learner.pkl")
